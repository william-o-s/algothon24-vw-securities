# %% [markdown]
# # Stationarity Testing

# %% [markdown]
# This notebook tests each stock for stationary data.
# 1. Price data is assumed to be an I(1) series while log returns are an I(0) series. This is verified through:
#     1. ACF plot
#     2. PACF plot
#     3. ADF test
#     4. KPSS test

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import warnings

from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.tools.sm_exceptions import InterpolationWarning
warnings.simplefilter('ignore', InterpolationWarning)

# %%
# Make plot directories
for dirname in ['acf-pacf/']:
    if not os.path.isdir(dirname):
        os.makedirs(dirname)

# %%
# Import data
stock_names = [f"stock{i}" for i in range(50)]
df = pd.read_csv('prices.txt', engine='python', sep='   ', header=None, names=stock_names)
df.head()
# Out:
#    stock0  stock1  stock2  stock3  stock4  stock5  stock6  stock7  stock8  \
# 0   13.46   71.65   48.46   50.52   52.10   13.00   18.98   47.71   69.49
# 1   13.48   72.10   48.52   50.50   52.06   12.95   18.95   47.84   69.73
# 2   13.47   72.35   48.48   50.62   51.80   12.79   18.98   47.98   69.60
# 3   13.53   72.51   48.42   50.75   51.66   12.66   18.96   48.74   69.54
# 4   13.64   71.99   48.40   50.65   51.97   12.62   18.89   48.88   69.68
#
#    stock9  ...  stock40  stock41  stock42  stock43  stock44  stock45  stock46  \
# 0   49.96  ...    32.64    55.76    14.46    58.94    36.71    52.62    49.33
# 1   49.93  ...    32.52    55.97    14.44    59.81    36.64    52.58    49.20
# 2   49.33  ...    32.48    56.34    14.50    59.04    36.89    52.49    49.48
# 3   49.67  ...    32.59    56.32    14.40    58.73    36.94    52.40    49.42
# 4   49.46  ...    32.64    56.32    14.36    59.01    37.03    52.44    49.79
#
#    stock47  stock48  stock49
# 0    36.22    49.00    56.09
# 1    36.27    48.84    56.08
# 2    36.39    48.56    55.90
# 3    36.41    49.00    56.14
# 4    36.42    48.14    55.90
#
# [5 rows x 50 columns]

# %% [markdown]
# ### Autocorrelation + Partial Autocorrelation Plots

# %%
def acf_pacf_plot(data, lags=20):
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
    sm.graphics.tsa.plot_acf(data.values.squeeze(), ax=ax[0], lags=lags)
    sm.graphics.tsa.plot_pacf(data.values.squeeze(), ax=ax[1], lags=lags)
    plt.suptitle(data.name)
    fig.savefig(f"acf-pacf/{data.name}.png")
    plt.close(fig)

# Plot ACF/PACF of all stocks
for stock in stocks:
    acf_pacf_plot(df[stock])

# %% [markdown]
# ### Stationarity Test

# %%
def adf_test(series, significance=0.05) -> bool:
    test = adfuller(series, autolag='AIC')

    if significance <= 0.01:
        confidence = '1%'
    elif significance <= 0.05:
        confidence = '5%'
    else:
        confidence = '10%'

    return test[1] <= significance and test[0] <= test[4][confidence]

def kpss_test(series, significance=0.05) -> bool:
    test = kpss(series, regression='c', nlags='auto', )

    if significance <= 0.01:
        confidence = '1%'
    elif significance <= 0.025:
        confidence = '2.5%'
    elif significance <= 0.05:
        confidence = '5%'
    else:
        confidence = '10%'

    return test[1] <= significance and test[0] <= test[3][confidence]

def is_stationary(series, significance=0.05):
    adf = adf_test(series, significance)
    kpss = kpss_test(series, significance)
    
    if adf and kpss:
        return 'stationary'
    elif kpss:
        return 'trend'
    elif adf:
        return 'difference'
    else:
        return 'non-stationary'

# %%
prices = []
log_returns = []
lag_1s = []
lag_2s = []
lag_3s = []

for stock_name, price_data in df.items():
    log_return = np.log1p(price_data.pct_change()).dropna()
    lag_1 = price_data.diff(periods=1).dropna()
    lag_2 = price_data.diff(periods=2).dropna()
    lag_3 = price_data.diff(periods=3).dropna()

    prices.append(is_stationary(price_data))
    log_returns.append(is_stationary(log_return))
    lag_1s.append(is_stationary(lag_1))
    lag_2s.append(is_stationary(lag_2))
    lag_3s.append(is_stationary(lag_3))

pd.DataFrame({'Price': prices, 'Log Returns': log_returns, 'Lag-1': lag_1s, 'Lag-2': lag_2s, 'Lag-3': lag_3s}, index=stock_names)
# Out:
#                   Price Log Returns       Lag-1       Lag-2       Lag-3
# stock0   non-stationary  difference  difference  difference  difference
# stock1   non-stationary  difference  difference  difference  difference
# stock2   non-stationary  difference  difference  difference  difference
# stock3   non-stationary  difference  difference  difference  difference
# stock4   non-stationary  difference  difference  difference  difference
# stock5   non-stationary  difference  difference  difference  difference
# stock6   non-stationary  difference  difference  difference  difference
# stock7   non-stationary  difference  difference  difference  difference
# stock8       difference  difference  difference  difference  difference
# stock9   non-stationary  difference  difference  difference  difference
# stock10  non-stationary  difference  difference  difference  difference
# stock11  non-stationary  difference  difference  difference  difference
# stock12  non-stationary  difference  difference  difference  difference
# stock13  non-stationary  difference  difference  difference  difference
# stock14  non-stationary  difference  difference  difference  difference
# stock15  non-stationary  difference  difference  difference  difference
# stock16  non-stationary  difference  difference  difference  difference
# stock17  non-stationary  difference  difference  difference  difference
# stock18  non-stationary  difference  difference  difference  difference
# stock19  non-stationary  difference  difference  difference  difference
# stock20  non-stationary  difference  difference  difference  difference
# stock21  non-stationary  difference  difference  difference  difference
# stock22  non-stationary  difference  difference  difference  difference
# stock23  non-stationary  difference  difference  difference  difference
# stock24  non-stationary  difference  difference  difference  difference
# stock25  non-stationary  difference  difference  difference  difference
# stock26  non-stationary  difference  difference  difference  difference
# stock27  non-stationary  difference  difference  difference  difference
# stock28  non-stationary  difference  difference  difference  difference
# stock29  non-stationary  difference  difference  difference  difference
# stock30  non-stationary  difference  difference  difference  difference
# stock31  non-stationary  difference  difference  difference  difference
# stock32  non-stationary  difference  difference  difference  difference
# stock33  non-stationary  difference  difference  difference  difference
# stock34  non-stationary  difference  difference  difference  difference
# stock35  non-stationary  difference  difference  difference  difference
# stock36  non-stationary  difference  difference  difference  difference
# stock37  non-stationary  difference  difference  difference  difference
# stock38  non-stationary  difference  difference  difference  difference
# stock39  non-stationary  difference  difference  difference  difference
# stock40  non-stationary  difference  difference  difference  difference
# stock41  non-stationary  difference  difference  difference  difference
# stock42  non-stationary  difference  difference  difference  difference
# stock43      difference  difference  difference  difference  difference
# stock44  non-stationary  difference  difference  difference  difference
# stock45  non-stationary  difference  difference  difference  difference
# stock46  non-stationary  difference  difference  difference  difference
# stock47  non-stationary  difference  difference  difference  difference
# stock48  non-stationary  difference  difference  difference  difference
# stock49  non-stationary  difference  difference  difference  difference

# %% [markdown]
# # Hurst Exponent

# %%
import numpy as np
import matplotlib.pyplot as plt
from hurst import compute_Hc

def hurst(stock_name, window=-100):
    # Evaluate Hurst equation
    stock_prices = df[stock_name].iloc[window:]
    H, c, data = compute_Hc(stock_prices, kind='price', simplified=True)

    # print("H={:.4f}, c={:.4f}".format(H,c))
    return H, c

def interpret(H, threshold=0.3):
    if H < threshold:
        return('anti-persistent behaviour')
    if H > (1 - threshold):
        return('persistent behaviour')
    return('Brownian Motion')

results = [hurst(stock_name, -250) for stock_name in df.columns]
hurst_df = pd.DataFrame(results, columns=['H', 'c'])
hurst_df['behaviour'] = hurst_df.apply(lambda row: interpret(row['H'], 0.4), axis=1)
hurst_df
# Out:
#            H         c                  behaviour
# 0   0.846762  0.564462       persistent behaviour
# 1   0.571684  1.283309            Brownian Motion
# 2   0.657656  0.876060       persistent behaviour
# 3   0.659046  0.828771       persistent behaviour
# 4   0.495511  1.188831            Brownian Motion
# 5   0.821999  0.565808       persistent behaviour
# 6   0.713595  0.812322       persistent behaviour
# 7   0.542719  1.179717            Brownian Motion
# 8   0.497729  1.296357            Brownian Motion
# 9   0.458486  1.474364            Brownian Motion
# 10  0.564256  1.099005            Brownian Motion
# 11  0.572902  1.246293            Brownian Motion
# 12  0.446535  1.554745            Brownian Motion
# 13  0.398259  1.742811  anti-persistent behaviour
# 14  0.340674  1.963949  anti-persistent behaviour
# 15  0.561288  1.222377            Brownian Motion
# 16  0.589477  1.118470            Brownian Motion
# 17  0.510063  1.206320            Brownian Motion
# 18  0.550528  1.142174            Brownian Motion
# 19  0.672895  0.919072       persistent behaviour
# 20  0.431366  2.080457            Brownian Motion
# 21  0.706040  0.646542       persistent behaviour
# 22  0.663307  0.877749       persistent behaviour
# 23  0.527867  1.138270            Brownian Motion
# 24  0.737590  0.737403       persistent behaviour
# 25  0.568059  1.118432            Brownian Motion
# 26  0.559880  1.252662            Brownian Motion
# 27  0.855783  0.700707       persistent behaviour
# 28  0.517396  1.299222            Brownian Motion
# 29  0.573548  1.323023            Brownian Motion
# 30  0.497898  1.510627            Brownian Motion
# 31  0.693866  0.811862       persistent behaviour
# 32  0.427754  1.690143            Brownian Motion
# 33  0.633210  0.796233       persistent behaviour
# 34  0.647921  0.836509       persistent behaviour
# 35  0.337246  2.329425  anti-persistent behaviour
# 36  0.438484  1.491556            Brownian Motion
# 37  0.619795  1.034416       persistent behaviour
# 38  0.749843  0.846836       persistent behaviour
# 39  0.736362  0.781649       persistent behaviour
# 40  0.623708  1.164399       persistent behaviour
# 41  0.493148  1.445257            Brownian Motion
# 42  0.594749  1.029692            Brownian Motion
# 43  0.537640  1.082157            Brownian Motion
# 44  0.554606  1.333721            Brownian Motion
# 45  0.448041  1.550424            Brownian Motion
# 46  0.735742  0.781188       persistent behaviour
# 47  0.573431  1.380503            Brownian Motion
# 48  0.482982  1.651959            Brownian Motion
# 49  0.490118  1.216171            Brownian Motion
