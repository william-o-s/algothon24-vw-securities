# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from statsmodels.tsa.stattools import adfuller

# %%
# Import data
df = pd.read_csv('prices.txt', engine='python', sep='   ', header=None, names=[f"stock{i}" for i in range(50)])
df
# Out:
#      stock0  stock1  stock2  stock3  stock4  stock5  stock6  stock7  stock8  \
# 0     13.46   71.65   48.46   50.52   52.10   13.00   18.98   47.71   69.49
# 1     13.48   72.10   48.52   50.50   52.06   12.95   18.95   47.84   69.73
# 2     13.47   72.35   48.48   50.62   51.80   12.79   18.98   47.98   69.60
# 3     13.53   72.51   48.42   50.75   51.66   12.66   18.96   48.74   69.54
# 4     13.64   71.99   48.40   50.65   51.97   12.62   18.89   48.88   69.68
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 745   10.32   63.28   45.54   43.35   52.64    7.91   17.30   55.30   67.83
# 746   10.32   63.34   45.56   43.28   52.73    7.87   17.26   54.92   67.95
# 747   10.32   63.23   45.55   43.25   52.66    7.83   17.32   54.67   67.94
# 748   10.20   63.12   45.56   43.19   52.51    7.71   17.33   55.18   67.99
# 749   10.29   63.32   45.55   43.12   52.52    7.72   17.37   54.97   67.95
#
#      stock9  ...  stock40  stock41  stock42  stock43  stock44  stock45  \
# 0     49.96  ...    32.64    55.76    14.46    58.94    36.71    52.62
# 1     49.93  ...    32.52    55.97    14.44    59.81    36.64    52.58
# 2     49.33  ...    32.48    56.34    14.50    59.04    36.89    52.49
# 3     49.67  ...    32.59    56.32    14.40    58.73    36.94    52.40
# 4     49.46  ...    32.64    56.32    14.36    59.01    37.03    52.44
# ..      ...  ...      ...      ...      ...      ...      ...      ...
# 745   58.73  ...    28.81    79.78    10.85    61.76    30.12    48.51
# 746   58.62  ...    28.78    80.46    10.77    61.49    29.85    48.40
# 747   59.15  ...    28.73    81.15    10.75    60.36    29.77    48.41
# 748   59.64  ...    28.73    82.22    10.81    59.24    29.61    48.42
# 749   59.48  ...    28.70    82.13    10.86    58.73    29.45    48.44
#
#      stock46  stock47  stock48  stock49
# 0      49.33    36.22    49.00    56.09
# 1      49.20    36.27    48.84    56.08
# 2      49.48    36.39    48.56    55.90
# 3      49.42    36.41    49.00    56.14
# 4      49.79    36.42    48.14    55.90
# ..       ...      ...      ...      ...
# 745    82.09    34.95    35.80    52.57
# 746    81.43    34.99    35.58    53.10
# 747    81.90    35.00    35.45    53.21
# 748    81.33    35.19    35.57    53.01
# 749    80.81    35.41    35.71    53.15
#
# [750 rows x 50 columns]

# %%
def adftest(stock_name):
    print(f"##### ADF Test for {stock_name} #####")

    prices = df[stock_name].iloc[-100:]
    returns = np.log1p(prices.pct_change())
    returns = returns[~np.isnan(returns)]

    print('Returns')
    test = adfuller(returns)
    dfoutput = pd.Series(
        test[0:4],
        index=[
            "Test Statistic",
            "p-value",
            "#Lags Used",
            "Number of Observations Used",
        ],
    )
    for key, value in test[4].items():
        dfoutput["Critical Value (%s)" % key] = value
    print(dfoutput)
    print()

for stock_name in df.columns:
    adftest(stock_name)
# Out:
# ##### ADF Test for stock0 #####
# Returns
# Test Statistic                -9.149109e+00
# p-value                        2.716832e-15
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock1 #####
# Returns
# Test Statistic                -1.000819e+01
# p-value                        1.807875e-17
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock2 #####
# Returns
# Test Statistic                 -5.205852
# p-value                         0.000009
# #Lags Used                      3.000000
# Number of Observations Used    95.000000
# Critical Value (1%)            -3.501137
# Critical Value (5%)            -2.892480
# Critical Value (10%)           -2.583275
# dtype: float64
#
# ##### ADF Test for stock3 #####
# Returns
# Test Statistic                -8.277175e+00
# p-value                        4.622842e-13
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock4 #####
# Returns
# Test Statistic                -1.198507e+01
# p-value                        3.629109e-22
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock5 #####
# Returns
# Test Statistic                 -5.521902
# p-value                         0.000002
# #Lags Used                      3.000000
# Number of Observations Used    95.000000
# Critical Value (1%)            -3.501137
# Critical Value (5%)            -2.892480
# Critical Value (10%)           -2.583275
# dtype: float64
#
# ##### ADF Test for stock6 #####
# Returns
# Test Statistic                -9.965492e+00
# p-value                        2.313006e-17
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock7 #####
# Returns
# Test Statistic                -6.789267e+00
# p-value                        2.387711e-09
# #Lags Used                     3.000000e+00
# Number of Observations Used    9.500000e+01
# Critical Value (1%)           -3.501137e+00
# Critical Value (5%)           -2.892480e+00
# Critical Value (10%)          -2.583275e+00
# dtype: float64
#
# ##### ADF Test for stock8 #####
# Returns
# Test Statistic                -9.327048e+00
# p-value                        9.548359e-16
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock9 #####
# Returns
# Test Statistic                 -4.150291
# p-value                         0.000799
# #Lags Used                      2.000000
# Number of Observations Used    96.000000
# Critical Value (1%)            -3.500379
# Critical Value (5%)            -2.892152
# Critical Value (10%)           -2.583100
# dtype: float64
#
# ##### ADF Test for stock10 #####
# Returns
# Test Statistic                -1.017505e+01
# p-value                        6.927714e-18
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock11 #####
# Returns
# Test Statistic                -1.135237e+01
# p-value                        9.922888e-21
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock12 #####
# Returns
# Test Statistic                -9.750207e+00
# p-value                        8.053580e-17
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock13 #####
# Returns
# Test Statistic                -9.413350e+00
# p-value                        5.755984e-16
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock14 #####
# Returns
# Test Statistic                -8.799192e+00
# p-value                        2.135098e-14
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock15 #####
# Returns
# Test Statistic                -1.005459e+01
# p-value                        1.383738e-17
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock16 #####
# Returns
# Test Statistic                -8.506641e+00
# p-value                        1.197942e-13
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock17 #####
# Returns
# Test Statistic                -8.638942e+00
# p-value                        5.492760e-14
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock18 #####
# Returns
# Test Statistic                -6.067815e+00
# p-value                        1.170267e-07
# #Lags Used                     3.000000e+00
# Number of Observations Used    9.500000e+01
# Critical Value (1%)           -3.501137e+00
# Critical Value (5%)           -2.892480e+00
# Critical Value (10%)          -2.583275e+00
# dtype: float64
#
# ##### ADF Test for stock19 #####
# Returns
# Test Statistic                -9.115485e+00
# p-value                        3.311271e-15
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock20 #####
# Returns
# Test Statistic                -9.506019e+00
# p-value                        3.345755e-16
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock21 #####
# Returns
# Test Statistic                -6.844471e+00
# p-value                        1.757125e-09
# #Lags Used                     3.000000e+00
# Number of Observations Used    9.500000e+01
# Critical Value (1%)           -3.501137e+00
# Critical Value (5%)           -2.892480e+00
# Critical Value (10%)          -2.583275e+00
# dtype: float64
#
# ##### ADF Test for stock22 #####
# Returns
# Test Statistic                -1.114174e+01
# p-value                        3.095970e-20
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock23 #####
# Returns
# Test Statistic                -1.109794e+01
# p-value                        3.930798e-20
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock24 #####
# Returns
# Test Statistic                -1.035085e+01
# p-value                        2.539080e-18
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock25 #####
# Returns
# Test Statistic                -9.288381e+00
# p-value                        1.198160e-15
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock26 #####
# Returns
# Test Statistic                -1.119399e+01
# p-value                        2.330964e-20
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock27 #####
# Returns
# Test Statistic                -8.526912e+00
# p-value                        1.063080e-13
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock28 #####
# Returns
# Test Statistic                -1.056385e+01
# p-value                        7.606080e-19
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock29 #####
# Returns
# Test Statistic                -1.171408e+01
# p-value                        1.465412e-21
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock30 #####
# Returns
# Test Statistic                 -4.513094
# p-value                         0.000186
# #Lags Used                      3.000000
# Number of Observations Used    95.000000
# Critical Value (1%)            -3.501137
# Critical Value (5%)            -2.892480
# Critical Value (10%)           -2.583275
# dtype: float64
#
# ##### ADF Test for stock31 #####
# Returns
# Test Statistic                -1.194217e+01
# p-value                        4.516417e-22
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock32 #####
# Returns
# Test Statistic                -1.053425e+01
# p-value                        8.986493e-19
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock33 #####
# Returns
# Test Statistic                -1.232128e+01
# p-value                        6.742224e-23
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock34 #####
# Returns
# Test Statistic                 -3.292156
# p-value                         0.015233
# #Lags Used                     10.000000
# Number of Observations Used    88.000000
# Critical Value (1%)            -3.506944
# Critical Value (5%)            -2.894990
# Critical Value (10%)           -2.584615
# dtype: float64
#
# ##### ADF Test for stock35 #####
# Returns
# Test Statistic                -9.281238e+00
# p-value                        1.249492e-15
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock36 #####
# Returns
# Test Statistic                -5.759903e+00
# p-value                        5.704322e-07
# #Lags Used                     6.000000e+00
# Number of Observations Used    9.200000e+01
# Critical Value (1%)           -3.503515e+00
# Critical Value (5%)           -2.893508e+00
# Critical Value (10%)          -2.583824e+00
# dtype: float64
#
# ##### ADF Test for stock37 #####
# Returns
# Test Statistic                -1.106038e+01
# p-value                        4.826178e-20
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock38 #####
# Returns
# Test Statistic                 -3.596013
# p-value                         0.005838
# #Lags Used                      6.000000
# Number of Observations Used    92.000000
# Critical Value (1%)            -3.503515
# Critical Value (5%)            -2.893508
# Critical Value (10%)           -2.583824
# dtype: float64
#
# ##### ADF Test for stock39 #####
# Returns
# Test Statistic                -8.653297e+00
# p-value                        5.046999e-14
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock40 #####
# Returns
# Test Statistic                -8.303504e+00
# p-value                        3.960025e-13
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock41 #####
# Returns
# Test Statistic                -6.182236e+00
# p-value                        6.413678e-08
# #Lags Used                     1.000000e+00
# Number of Observations Used    9.700000e+01
# Critical Value (1%)           -3.499637e+00
# Critical Value (5%)           -2.891831e+00
# Critical Value (10%)          -2.582928e+00
# dtype: float64
#
# ##### ADF Test for stock42 #####
# Returns
# Test Statistic                 -5.450176
# p-value                         0.000003
# #Lags Used                      3.000000
# Number of Observations Used    95.000000
# Critical Value (1%)            -3.501137
# Critical Value (5%)            -2.892480
# Critical Value (10%)           -2.583275
# dtype: float64
#
# ##### ADF Test for stock43 #####
# Returns
# Test Statistic                -9.958933e+00
# p-value                        2.402313e-17
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock44 #####
# Returns
# Test Statistic                 -2.530925
# p-value                         0.108130
# #Lags Used                      6.000000
# Number of Observations Used    92.000000
# Critical Value (1%)            -3.503515
# Critical Value (5%)            -2.893508
# Critical Value (10%)           -2.583824
# dtype: float64
#
# ##### ADF Test for stock45 #####
# Returns
# Test Statistic                -9.409124e+00
# p-value                        5.900321e-16
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock46 #####
# Returns
# Test Statistic                -1.101027e+01
# p-value                        6.351245e-20
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock47 #####
# Returns
# Test Statistic                -9.265918e+00
# p-value                        1.367143e-15
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock48 #####
# Returns
# Test Statistic                -8.479495e+00
# p-value                        1.405676e-13
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64
#
# ##### ADF Test for stock49 #####
# Returns
# Test Statistic                -9.344675e+00
# p-value                        8.610037e-16
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -3.498910e+00
# Critical Value (5%)           -2.891516e+00
# Critical Value (10%)          -2.582760e+00
# dtype: float64

# %% [markdown]
# # Hurst Exponent

# %%
import numpy as np
import matplotlib.pyplot as plt
from hurst import compute_Hc

def hurst(stock_name, window=-100):
    # Evaluate Hurst equation
    stock_prices = df[stock_name].iloc[window:]
    H, c, data = compute_Hc(stock_prices, kind='price', simplified=True)

    # print("H={:.4f}, c={:.4f}".format(H,c))
    return H, c

def interpret(H, threshold=0.3):
    if H < threshold:
        return('anti-persistent behaviour')
    if H > (1 - threshold):
        return('persistent behaviour')
    return('Brownian Motion')

results = [hurst(stock_name, -250) for stock_name in df.columns]
hurst_df = pd.DataFrame(results, columns=['H', 'c'])
hurst_df['behaviour'] = hurst_df.apply(lambda row: interpret(row['H'], 0.4), axis=1)
hurst_df
# Out:
#            H         c                  behaviour
# 0   0.846762  0.564462       persistent behaviour
# 1   0.571684  1.283309            Brownian Motion
# 2   0.657656  0.876060       persistent behaviour
# 3   0.659046  0.828771       persistent behaviour
# 4   0.495511  1.188831            Brownian Motion
# 5   0.821999  0.565808       persistent behaviour
# 6   0.713595  0.812322       persistent behaviour
# 7   0.542719  1.179717            Brownian Motion
# 8   0.497729  1.296357            Brownian Motion
# 9   0.458486  1.474364            Brownian Motion
# 10  0.564256  1.099005            Brownian Motion
# 11  0.572902  1.246293            Brownian Motion
# 12  0.446535  1.554745            Brownian Motion
# 13  0.398259  1.742811  anti-persistent behaviour
# 14  0.340674  1.963949  anti-persistent behaviour
# 15  0.561288  1.222377            Brownian Motion
# 16  0.589477  1.118470            Brownian Motion
# 17  0.510063  1.206320            Brownian Motion
# 18  0.550528  1.142174            Brownian Motion
# 19  0.672895  0.919072       persistent behaviour
# 20  0.431366  2.080457            Brownian Motion
# 21  0.706040  0.646542       persistent behaviour
# 22  0.663307  0.877749       persistent behaviour
# 23  0.527867  1.138270            Brownian Motion
# 24  0.737590  0.737403       persistent behaviour
# 25  0.568059  1.118432            Brownian Motion
# 26  0.559880  1.252662            Brownian Motion
# 27  0.855783  0.700707       persistent behaviour
# 28  0.517396  1.299222            Brownian Motion
# 29  0.573548  1.323023            Brownian Motion
# 30  0.497898  1.510627            Brownian Motion
# 31  0.693866  0.811862       persistent behaviour
# 32  0.427754  1.690143            Brownian Motion
# 33  0.633210  0.796233       persistent behaviour
# 34  0.647921  0.836509       persistent behaviour
# 35  0.337246  2.329425  anti-persistent behaviour
# 36  0.438484  1.491556            Brownian Motion
# 37  0.619795  1.034416       persistent behaviour
# 38  0.749843  0.846836       persistent behaviour
# 39  0.736362  0.781649       persistent behaviour
# 40  0.623708  1.164399       persistent behaviour
# 41  0.493148  1.445257            Brownian Motion
# 42  0.594749  1.029692            Brownian Motion
# 43  0.537640  1.082157            Brownian Motion
# 44  0.554606  1.333721            Brownian Motion
# 45  0.448041  1.550424            Brownian Motion
# 46  0.735742  0.781188       persistent behaviour
# 47  0.573431  1.380503            Brownian Motion
# 48  0.482982  1.651959            Brownian Motion
# 49  0.490118  1.216171            Brownian Motion
